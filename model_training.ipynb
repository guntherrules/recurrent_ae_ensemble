# %%
import torch
import torch.nn as nn
import sklearn.metrics as metrics
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.model_selection as model_selection
import os

from model import lib as MyModels

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Training Functions

# %%
def train_one_epoch(model, trainloader, optimizer, epoch_index, lossfunc, clipping=False):
    running_loss = 0.

    for i, data in enumerate(trainloader):
        # Input-label pair
        inputs, labels = data 

        # Gradient INIT
        optimizer.zero_grad()
        # Predictions and loss for current batch
        outputs = model(inputs.to(device))
        loss = lossfunc(inputs.to(device), outputs.to(device))
        # Gradient computation and learning weight adjust
        loss.backward()
        
        if clipping==True:
            nn.utils.clip_grad_norm_(model.parameters(), 1)
        optimizer.step()
        # Gather data
        running_loss += loss.item()
            
    last_loss = running_loss / (i+1)
    
    return last_loss

# %%
def train_model(model, trainloader, validationloader, epochs, learning_rate, patience, report_every_n_epochs, clipping=True):
    
    trigger_times = 0
    last_loss = 0.

    optimizer = torch.optim.Adadelta(model.parameters(), lr=learning_rate)
    mse = nn.MSELoss(reduction='sum')
    train_loss = []
    val_loss = []

    for epoch in range(epochs):
        running_vloss = 0.

        # Make sure gradient tracking is on, and do a pass over the data
        model.train(True)
        avg_loss = train_one_epoch(model, trainloader, optimizer, epoch, mse, clipping)
        train_loss.append(avg_loss)

        # We don't need gradients on to do reporting
        model.train(False)

        running_vloss = 0.0
        for i, vdata in enumerate(validationloader):
            vinputs, vlabels = vdata
            voutputs = model(vinputs.to(device))
            vloss = mse(vinputs.to(device), voutputs.to(device)).cpu().detach()
            running_vloss += vloss

        avg_vloss = running_vloss / (i + 1)
        val_loss.append(avg_vloss)
        
        if (epoch+1) % report_every_n_epochs == 0:
            print('Epoch {}:'.format(epoch + 1))
            print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))

        # Early stopping 
        # stop if training loss does not decrease significantly
        if abs(avg_loss-last_loss) < threshold:
            trigger_times += 1

            if trigger_times >= patience:
                print('Early stopping!\nStart to test process.')
                return model

        else:
            trigger_times = 0
        last_loss = avg_loss

    return model, [train_loss, val_loss]

# %%
def train_ensemble(
            train_dataset,
            validation_dataset,
            num_models = 40,
            hidden_layers = 8,
            skip_max = 30,
            epochs = 50, 
            learning_rate = 0.05,
            report_every_n_epochs = 10, 
            clipping=True, 
            patience = 10):

    trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=len(train_dataset), shuffle=True)
    validationloader = torch.utils.data.DataLoader(validation_dataset, batch_size=len(validation_dataset), shuffle=True)
    
    time_steps = len(train_dataset[0][0])
    train_errors = np.empty((num_models, len(train_dataset), time_steps))
    val_errors = np.empty((num_models, len(validation_dataset), time_steps))
    train_loss = np.empty((num_models, epochs))
    val_loss = np.empty((num_models, epochs))
    model_params = pd.DataFrame(columns=['path','enc_skip_size', 'dec_skip_size', 'train_errors', 'val_errors', 'train_loss', 'val_loss'])
  
    for model_counter in range(num_models):
        print('Model %s'%model_counter)
        example_train, example_label = next(iter(trainloader))
        model = MyModels.rand_seq2seq(example_train.shape[-1], hidden_layers, skip_max, device=device)
        
        model, loss = train_model(model, trainloader, validationloader, epochs, learning_rate, patience, report_every_n_epochs)
        enc_skip_size, dec_skip_size = model.skip_sizes
        model_path = './drive/MyDrive/model_checkpoints/model_%s'%model_counter
        torch.save(model.state_dict(), model_path)
        train_loss[model_counter] = loss[0]
        val_loss[model_counter] = loss[1]
        model.train(False)
        model.cpu()
        
        train_errors[model_counter] = model_errors(train_dataset, model)
        val_errors[model_counter] = model_errors(validation_dataset, model)
        
        df = pd.DataFrame([[model_path, 
                           enc_skip_size, 
                           dec_skip_size, 
                           train_errors[model_counter], 
                           val_errors[model_counter],
                           train_loss[model_counter],
                           val_loss[model_counter]]],
                          columns = model_params.columns)
        
        model_params = pd.concat((model_params, df), ignore_index=True)
        del model
        
    return model_params, train_errors, val_errors

# %% [markdown]
# # Training

# %%
def minmax_scaling(dataset):
    minimum = np.min(dataset)
    maximum = np.max(dataset)
    return (dataset-minimum)/(maximum-minimum)

# %%
def sum_of_squared_errors(_inputs, _outputs):
    # outlier score of each timeseries for each timestep
    inputs = _inputs.detach().numpy()
    outputs = _outputs.detach().numpy()
    square_errors = np.square(inputs-outputs)
    return np.sum(square_errors, axis=-1)

def Z_score(_inputs):
    mu = np.mean(_inputs)
    std = np.std(_inputs)
    return (_inputs-mu)/std

def model_errors(dataset, model):
    inputs, labels = dataset.dataset[dataset.indices]
    output = model(inputs)
    return sum_of_squared_errors(inputs, output)

# %%
def make_label(zscore):
  y_pred = np.zeros(np.shape(zscore))
  threshold = 0
  y_pred[zscore>threshold] = 1
  y_pred[zscore<threshold] = 0
  return y_pred

# %%
def evaluate(label, score):
  print('ROC-AUC: ', metrics.roc_auc_score(label, score))
  pred = make_label(score)
  print('Accuracy: ', metrics.accuracy_score(label, pred))
  print('Precision: ', metrics.precision_score(label, pred))
  print('Recall: ', metrics.recall_score(label, pred))
  print('F1: ', metrics.f1_score(label, pred))

# %% [markdown]
# ## Train on CHB-MIT dataset
# ### Load the Data

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def prepare_CHB_data(_input):
    scaled = minmax_scaling(_input)
    scaled = np.transpose(scaled, (0,2,1))
    return torch.from_numpy(scaled).float()

# %%
file = np.load('./drive/MyDrive/dataset/CHB_MIT/eeg-seizure_train.npz')
traindata = prepare_CHB_data(file['train_signals'])
trainlabel = torch.from_numpy(file['train_labels'])

file = np.load('./drive/MyDrive/dataset/CHB_MIT/eeg-seizure_test.npz')
testdata = prepare_CHB_data(file['test_signals'])

file = np.load('./drive/MyDrive/dataset/CHB_MIT/eeg-seizure_val.npz')
valdata = prepare_CHB_data(file['val_signals'])
vallabel = torch.from_numpy(file['val_labels'])

# %%
traindataset_full = torch.utils.data.TensorDataset(traindata, trainlabel)
validationdataset_full = torch.utils.data.TensorDataset(valdata, vallabel)
traindataset, _ = torch.utils.data.random_split(traindataset_full, [0.1, 0.9], generator=torch.Generator().manual_seed(42))
validationdataset, _ = torch.utils.data.random_split(validationdataset_full, [0.1, 0.9], generator=torch.Generator().manual_seed(42))

# %%
len(traindataset)
# Out:
# 9417

# %% [markdown]
# ### Start Training

# %%
import gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
model, t_err, v_err= train_ensemble(traindataset, validationdataset, num_models=40, hidden_layers=8, epochs=100, learning_rate=0.05, patience=5, skip_max=30)
# Out:
# Model 0
# Epoch 10:
# LOSS train 20770946.0 valid 4724215.0
# Epoch 20:
# LOSS train 20310460.0 valid 4622130.0
# Epoch 30:
# LOSS train 19830232.0 valid 4517402.5
# Epoch 40:
# LOSS train 19364304.0 valid 4417818.5
# Epoch 50:
# LOSS train 18905528.0 valid 4313165.0
# Epoch 60:
# LOSS train 18442224.0 valid 4211115.5
# Epoch 70:
# LOSS train 17978710.0 valid 4106047.5
# Epoch 80:
# LOSS train 17499148.0 valid 4000321.75
# Epoch 90:
# LOSS train 17023444.0 valid 3893281.25
# Epoch 100:
# LOSS train 16544711.0 valid 3785521.5
# Model 1
# Epoch 10:
# LOSS train 14610750.0 valid 3364433.5
# Epoch 20:
# LOSS train 14340751.0 valid 3304504.5
# Epoch 30:
# LOSS train 14069499.0 valid 3244272.75
# Epoch 40:
# LOSS train 13786525.0 valid 3181127.0
# Epoch 50:
# LOSS train 13495844.0 valid 3114405.5
# Epoch 60:
# LOSS train 13174641.0 valid 3045903.5
# Epoch 70:
# LOSS train 12861974.0 valid 2971654.0
# Epoch 80:
# LOSS train 12510668.0 valid 2895586.75
# Epoch 90:
# LOSS train 12158105.0 valid 2814548.25
# Epoch 100:
# LOSS train 11786142.0 valid 2725050.75
# Model 2
# Epoch 10:
# LOSS train 17865088.0 valid 4096936.25
# Epoch 20:
# LOSS train 17620822.0 valid 4042364.5
# Epoch 30:
# LOSS train 17373174.0 valid 3987568.25
# Epoch 40:
# LOSS train 17122790.0 valid 3932099.75
# Epoch 50:
# LOSS train 16868580.0 valid 3875680.5
# Epoch 60:
# LOSS train 16612371.0 valid 3817236.25
# Epoch 70:
# LOSS train 16341973.0 valid 3757893.0
# Epoch 80:
# LOSS train 16065344.0 valid 3696124.5
# Epoch 90:
# LOSS train 15777830.0 valid 3630684.5
# Epoch 100:
# LOSS train 15471741.0 valid 3564006.5
# Model 3
# Epoch 10:
# LOSS train 13800111.0 valid 3187112.0
# Epoch 20:
# LOSS train 13396124.0 valid 3100562.0
# Epoch 30:
# LOSS train 12994044.0 valid 3011816.5
# Epoch 40:
# LOSS train 12573879.0 valid 2918811.5
# Epoch 50:
# LOSS train 12133261.0 valid 2816665.0
# Epoch 60:
# LOSS train 11681646.0 valid 2709979.5
# Epoch 70:
# LOSS train 11170184.0 valid 2603384.5
# Epoch 80:
# LOSS train 10689210.0 valid 2481229.25
# Epoch 90:
# LOSS train 10111346.0 valid 2350066.5
# Epoch 100:
# LOSS train 9477662.0 valid 2211010.75
# Model 4
# Epoch 10:
# LOSS train 18489264.0 valid 4236114.5
# Epoch 20:
# LOSS train 18135324.0 valid 4154694.0
# Epoch 30:
# LOSS train 17781252.0 valid 4076483.5
# Epoch 40:
# LOSS train 17414636.0 valid 3996766.75
# Epoch 50:
# LOSS train 17035800.0 valid 3910032.0
# Epoch 60:
# LOSS train 16658924.0 valid 3825854.25
# Epoch 70:
# LOSS train 16258368.0 valid 3736081.5
# Epoch 80:
# LOSS train 15860262.0 valid 3644065.0
# Epoch 90:
# LOSS train 15424660.0 valid 3546837.0
# Epoch 100:
# LOSS train 14981132.0 valid 3447276.25
# Model 5
# Epoch 10:
# LOSS train 11935242.0 valid 2774227.5
# Epoch 20:
# LOSS train 11621068.0 valid 2701152.5
# Epoch 30:
# LOSS train 11296532.0 valid 2626625.0
# Epoch 40:
# LOSS train 10948236.0 valid 2548201.75
# Epoch 50:
# LOSS train 10588490.0 valid 2465693.75
# Epoch 60:
# LOSS train 10190516.0 valid 2379526.0
# Epoch 70:
# LOSS train 9765963.0 valid 2281932.5
# Epoch 80:
# LOSS train 9301580.0 valid 2176756.5
# Epoch 90:
# LOSS train 8775542.0 valid 2054518.25
# Epoch 100:
# LOSS train 8182919.5 valid 1922422.5
# Model 6
# Epoch 10:
# LOSS train 15937988.0 valid 3658675.5
# Epoch 20:
# LOSS train 15599426.0 valid 3583791.5
# Epoch 30:
# LOSS train 15256614.0 valid 3507467.5
# Epoch 40:
# LOSS train 14912494.0 valid 3430587.75
# Epoch 50:
# LOSS train 14567016.0 valid 3353196.0
# Epoch 60:
# LOSS train 14211916.0 valid 3272759.5
# Epoch 70:
# LOSS train 13852059.0 valid 3192392.5
# Epoch 80:
# LOSS train 13475746.0 valid 3108221.5
# Epoch 90:
# LOSS train 13091439.0 valid 3018460.25
# Epoch 100:
# LOSS train 12687362.0 valid 2930426.75
# Model 7
# Epoch 10:
# LOSS train 20005048.0 valid 4561826.0
# Epoch 20:
# LOSS train 19625684.0 valid 4492119.0
# Epoch 30:
# LOSS train 19285872.0 valid 4404277.0
# Epoch 40:
# LOSS train 18934468.0 valid 4325568.0
# Epoch 50:
# LOSS train 18583840.0 valid 4243817.5
# Epoch 60:
# LOSS train 18172934.0 valid 4157299.5
# Epoch 70:
# LOSS train 17764296.0 valid 4068939.0
# Epoch 80:
# LOSS train 17342092.0 valid 3973370.5
# Epoch 90:
# LOSS train 16883180.0 valid 3867432.0
# Epoch 100:
# LOSS train 16371649.0 valid 3752125.5
# Model 8
# Epoch 10:
# LOSS train 14883884.0 valid 3440680.75
# Epoch 20:
# LOSS train 14666463.0 valid 3391689.25
# Epoch 30:
# LOSS train 14443976.0 valid 3341604.25
# Epoch 40:
# LOSS train 14217348.0 valid 3291113.0
# Epoch 50:
# LOSS train 13980552.0 valid 3236750.5
# Epoch 60:
# LOSS train 13738156.0 valid 3180651.5
# Epoch 70:
# LOSS train 13470816.0 valid 3123788.0
# Epoch 80:
# LOSS train 13216382.0 valid 3066013.0
# Epoch 90:
# LOSS train 12941234.0 valid 3001118.5
# Epoch 100:
# LOSS train 12621796.0 valid 2933073.0
# Model 9
# Epoch 10:
# LOSS train 13039090.0 valid 3021712.75
# Epoch 20:
# LOSS train 12744470.0 valid 2955314.5
# Epoch 30:
# LOSS train 12450521.0 valid 2887744.25
# Epoch 40:
# LOSS train 12150541.0 valid 2820659.25
# Epoch 50:
# LOSS train 11836794.0 valid 2749729.0
# Epoch 60:
# LOSS train 11511020.0 valid 2676734.5
# Epoch 70:
# LOSS train 11183496.0 valid 2598805.0
# Epoch 80:
# LOSS train 10822349.0 valid 2518286.0
# Epoch 90:
# LOSS train 10443181.0 valid 2431454.0
# Epoch 100:
# LOSS train 10038108.0 valid 2341349.25
# Model 10
# Epoch 10:
# LOSS train 20934476.0 valid 4760439.0
# Epoch 20:
# LOSS train 20386642.0 valid 4662643.0
# Epoch 30:
# LOSS train 19925072.0 valid 4551154.5
# Epoch 40:
# LOSS train 19448778.0 valid 4445337.5
# Epoch 50:
# LOSS train 18941794.0 valid 4327864.0
# Epoch 60:
# LOSS train 18448360.0 valid 4224809.0
# Epoch 70:
# LOSS train 18011252.0 valid 4120728.5
# Epoch 80:
# LOSS train 17505398.0 valid 4003795.25
# Epoch 90:
# LOSS train 16995252.0 valid 3892860.75
# Epoch 100:
# LOSS train 16497853.0 valid 3782509.0
# Model 11
# Epoch 10:
# LOSS train 15219788.0 valid 3504072.5
# Epoch 20:
# LOSS train 14924816.0 valid 3438878.5
# Epoch 30:
# LOSS train 14640028.0 valid 3375823.5
# Epoch 40:
# LOSS train 14340142.0 valid 3307659.5
# Epoch 50:
# LOSS train 14034530.0 valid 3239185.0
# Epoch 60:
# LOSS train 13715728.0 valid 3167210.0
# Epoch 70:
# LOSS train 13378432.0 valid 3091529.75
# Epoch 80:
# LOSS train 13020620.0 valid 3010148.75
# Epoch 90:
# LOSS train 12628830.0 valid 2921088.25
# Epoch 100:
# LOSS train 12194212.0 valid 2823104.0
# Model 12
# Epoch 10:
# LOSS train 15054616.0 valid 3469626.5
# Epoch 20:
# LOSS train 14735664.0 valid 3400393.0
# Epoch 30:
# LOSS train 14399150.0 valid 3325153.0
# Epoch 40:
# LOSS train 14036723.0 valid 3240625.5
# Epoch 50:
# LOSS train 13634982.0 valid 3148540.25
# Epoch 60:
# LOSS train 13201994.0 valid 3048986.5
# Epoch 70:
# LOSS train 12670405.0 valid 2936474.5
# Epoch 80:
# LOSS train 12070631.0 valid 2801551.5
# Epoch 90:
# LOSS train 11360326.0 valid 2634687.25
# Epoch 100:
# LOSS train 10572579.0 valid 2447327.5
# Model 13
# Epoch 10:
# LOSS train 12454114.0 valid 2888276.5
# Epoch 20:
# LOSS train 12272724.0 valid 2846967.0
# Epoch 30:
# LOSS train 12078628.0 valid 2803276.5
# Epoch 40:
# LOSS train 11863641.0 valid 2754404.5
# Epoch 50:
# LOSS train 11622837.0 valid 2699687.75
# Epoch 60:
# LOSS train 11350134.0 valid 2637437.0
# Epoch 70:
# LOSS train 11035703.0 valid 2566593.5
# Epoch 80:
# LOSS train 10661044.0 valid 2480592.5
# Epoch 90:
# LOSS train 10221073.0 valid 2377170.0
# Epoch 100:
# LOSS train 9679070.0 valid 2258773.0
# Model 14
# Epoch 10:
# LOSS train 13392822.0 valid 3096756.0
# Epoch 20:
# LOSS train 13134396.0 valid 3037257.5
# Epoch 30:
# LOSS train 12857293.0 valid 2974889.0
# Epoch 40:
# LOSS train 12548896.0 valid 2907176.25
# Epoch 50:
# LOSS train 12234202.0 valid 2834353.75
# Epoch 60:
# LOSS train 11876479.0 valid 2756394.75
# Epoch 70:
# LOSS train 11519678.0 valid 2670662.75
# Epoch 80:
# LOSS train 11110706.0 valid 2578072.0
# Epoch 90:
# LOSS train 10684442.0 valid 2473709.5
# Epoch 100:
# LOSS train 10186706.0 valid 2363321.0
# Model 15
# Epoch 10:
# LOSS train 14289430.0 valid 3278696.0
# Epoch 20:
# LOSS train 13892122.0 valid 3192442.5
# Epoch 30:
# LOSS train 13488976.0 valid 3100440.5
# Epoch 40:
# LOSS train 13054701.0 valid 3002859.5
# Epoch 50:
# LOSS train 12603982.0 valid 2899052.5
# Epoch 60:
# LOSS train 12141537.0 valid 2789315.0
# Epoch 70:
# LOSS train 11599454.0 valid 2678186.0
# Epoch 80:
# LOSS train 11083940.0 valid 2548000.5
# Epoch 90:
# LOSS train 10526984.0 valid 2418290.0
# Epoch 100:
# LOSS train 9922032.0 valid 2281036.75
# Model 16
# Epoch 10:
# LOSS train 17801536.0 valid 4078554.5
# Epoch 20:
# LOSS train 17454166.0 valid 4008274.0
# Epoch 30:
# LOSS train 17157008.0 valid 3927357.0
# Epoch 40:
# LOSS train 16821020.0 valid 3850493.0
# Epoch 50:
# LOSS train 16394592.0 valid 3773747.25
# Epoch 60:
# LOSS train 16065772.0 valid 3690523.5
# Epoch 70:
# LOSS train 15690928.0 valid 3614207.5
# Epoch 80:
# LOSS train 15321200.0 valid 3508539.5
# Epoch 90:
# LOSS train 14859952.0 valid 3404430.0
# Epoch 100:
# LOSS train 14363997.0 valid 3310737.5
# Model 17
# Epoch 10:
# LOSS train 17434330.0 valid 3986167.75
# Epoch 20:
# LOSS train 16999336.0 valid 3891432.5
# Epoch 30:
# LOSS train 16584189.0 valid 3800001.75
# Epoch 40:
# LOSS train 16183437.0 valid 3710006.25
# Epoch 50:
# LOSS train 15784830.0 valid 3623331.0
# Epoch 60:
# LOSS train 15386287.0 valid 3535229.0
# Epoch 70:
# LOSS train 14974102.0 valid 3441777.0
# Epoch 80:
# LOSS train 14548940.0 valid 3347055.75
# Epoch 90:
# LOSS train 14106856.0 valid 3245037.75
# Epoch 100:
# LOSS train 13627432.0 valid 3141077.5
# Model 18
# Epoch 10:
# LOSS train 13022985.0 valid 3014955.5
# Epoch 20:
# LOSS train 12758068.0 valid 2956237.5
# Epoch 30:
# LOSS train 12491754.0 valid 2897309.75
# Epoch 40:
# LOSS train 12222405.0 valid 2836752.75
# Epoch 50:
# LOSS train 11941082.0 valid 2774171.5
# Epoch 60:
# LOSS train 11661567.0 valid 2710745.0
# Epoch 70:
# LOSS train 11368773.0 valid 2644589.75
# Epoch 80:
# LOSS train 11055930.0 valid 2572967.5
# Epoch 90:
# LOSS train 10707086.0 valid 2499917.75
# Epoch 100:
# LOSS train 10347808.0 valid 2412587.75
# Model 19
# Epoch 10:
# LOSS train 12653094.0 valid 2927740.5
# Epoch 20:
# LOSS train 12368334.0 valid 2864819.0
# Epoch 30:
# LOSS train 12084432.0 valid 2799564.75
# Epoch 40:
# LOSS train 11793019.0 valid 2733792.0
# Epoch 50:
# LOSS train 11489048.0 valid 2666675.5
# Epoch 60:
# LOSS train 11172680.0 valid 2593724.75
# Epoch 70:
# LOSS train 10847121.0 valid 2521669.5
# Epoch 80:
# LOSS train 10492322.0 valid 2439719.0
# Epoch 90:
# LOSS train 10123518.0 valid 2358246.5
# Epoch 100:
# LOSS train 9725460.0 valid 2262671.5
# Model 20
# Epoch 10:
# LOSS train 15208182.0 valid 3508671.75
# Epoch 20:
# LOSS train 14889545.0 valid 3438041.5
# Epoch 30:
# LOSS train 14561988.0 valid 3363207.75
# Epoch 40:
# LOSS train 14222460.0 valid 3284553.5
# Epoch 50:
# LOSS train 13862821.0 valid 3205301.5
# Epoch 60:
# LOSS train 13487372.0 valid 3118962.5
# Epoch 70:
# LOSS train 13083568.0 valid 3030433.0
# Epoch 80:
# LOSS train 12669506.0 valid 2937029.75
# Epoch 90:
# LOSS train 12211609.0 valid 2830645.25
# Epoch 100:
# LOSS train 11732997.0 valid 2725348.5
# Model 21
# Epoch 10:
# LOSS train 7952012.0 valid 1876027.25
# Epoch 20:
# LOSS train 7731919.0 valid 1823898.25
# Epoch 30:
# LOSS train 7487382.0 valid 1770787.25
# Epoch 40:
# LOSS train 7246090.0 valid 1714585.25
# Epoch 50:
# LOSS train 6978553.0 valid 1654025.0
# Epoch 60:
# LOSS train 6710183.0 valid 1590734.25
# Epoch 70:
# LOSS train 6409397.0 valid 1525571.0
# Epoch 80:
# LOSS train 6124951.0 valid 1448393.0
# Epoch 90:
# LOSS train 5798894.0 valid 1380572.5
# Epoch 100:
# LOSS train 5460770.5 valid 1301170.25
# Model 22
# Epoch 10:
# LOSS train 14973976.0 valid 3458625.0
# Epoch 20:
# LOSS train 14658174.0 valid 3385392.25
# Epoch 30:
# LOSS train 14325956.0 valid 3311436.25
# Epoch 40:
# LOSS train 13984249.0 valid 3234671.75
# Epoch 50:
# LOSS train 13627500.0 valid 3154022.0
# Epoch 60:
# LOSS train 13259990.0 valid 3070612.25
# Epoch 70:
# LOSS train 12868366.0 valid 2984935.0
# Epoch 80:
# LOSS train 12468422.0 valid 2894598.0
# Epoch 90:
# LOSS train 12052978.0 valid 2797678.5
# Epoch 100:
# LOSS train 11596454.0 valid 2698973.5
# Model 23
# Epoch 10:
# LOSS train 15086650.0 valid 3472265.0
# Epoch 20:
# LOSS train 14597454.0 valid 3366506.75
# Epoch 30:
# LOSS train 14212190.0 valid 3280870.25
# Epoch 40:
# LOSS train 13750631.0 valid 3176408.75
# Epoch 50:
# LOSS train 13271250.0 valid 3058231.0
# Epoch 60:
# LOSS train 12750153.0 valid 2944436.5
# Epoch 70:
# LOSS train 12216114.0 valid 2823398.5
# Epoch 80:
# LOSS train 11657478.0 valid 2699863.5
# Epoch 90:
# LOSS train 11050285.0 valid 2562220.25
# Epoch 100:
# LOSS train 10429084.0 valid 2422066.75
# Model 24
# Epoch 10:
# LOSS train 17935186.0 valid 4096997.0
# Epoch 20:
# LOSS train 17453592.0 valid 3991478.25
# Epoch 30:
# LOSS train 16973434.0 valid 3885783.0
# Epoch 40:
# LOSS train 16506939.0 valid 3777251.25
# Epoch 50:
# LOSS train 15998157.0 valid 3667451.5
# Epoch 60:
# LOSS train 15507578.0 valid 3559804.5
# Epoch 70:
# LOSS train 15020223.0 valid 3448217.5
# Epoch 80:
# LOSS train 14518860.0 valid 3334311.75
# Epoch 90:
# LOSS train 14002505.0 valid 3221653.0
# Epoch 100:
# LOSS train 13454818.0 valid 3099303.25
# Model 25
# Epoch 10:
# LOSS train 14519948.0 valid 3352145.5
# Epoch 20:
# LOSS train 14310636.0 valid 3304295.5
# Epoch 30:
# LOSS train 14095857.0 valid 3255772.25
# Epoch 40:
# LOSS train 13875496.0 valid 3208002.0
# Epoch 50:
# LOSS train 13648046.0 valid 3158325.5
# Epoch 60:
# LOSS train 13424692.0 valid 3106804.25
# Epoch 70:
# LOSS train 13192206.0 valid 3053737.0
# Epoch 80:
# LOSS train 12948993.0 valid 2999532.0
# Epoch 90:
# LOSS train 12689477.0 valid 2941881.0
# Epoch 100:
# LOSS train 12414392.0 valid 2878021.75
# Model 26
# Epoch 10:
# LOSS train 16438830.0 valid 3769439.75
# Epoch 20:
# LOSS train 16106878.0 valid 3695553.5
# Epoch 30:
# LOSS train 15763675.0 valid 3618915.5
# Epoch 40:
# LOSS train 15398495.0 valid 3536435.5
# Epoch 50:
# LOSS train 15009418.0 valid 3451937.5
# Epoch 60:
# LOSS train 14602730.0 valid 3359306.0
# Epoch 70:
# LOSS train 14185026.0 valid 3267203.25
# Epoch 80:
# LOSS train 13727387.0 valid 3162037.75
# Epoch 90:
# LOSS train 13242641.0 valid 3051348.0
# Epoch 100:
# LOSS train 12751252.0 valid 2937626.0
# Model 27
# Epoch 10:
# LOSS train 19588296.0 valid 4487700.0
# Epoch 20:
# LOSS train 19281410.0 valid 4417017.0
# Epoch 30:
# LOSS train 18961532.0 valid 4349019.0
# Epoch 40:
# LOSS train 18654266.0 valid 4276968.0
# Epoch 50:
# LOSS train 18327626.0 valid 4206278.5
# Epoch 60:
# LOSS train 17999660.0 valid 4134064.0
# Epoch 70:
# LOSS train 17671068.0 valid 4060893.75
# Epoch 80:
# LOSS train 17332708.0 valid 3982387.0
# Epoch 90:
# LOSS train 16980644.0 valid 3902235.0
# Epoch 100:
# LOSS train 16590414.0 valid 3817188.5
# Model 28
# Epoch 10:
# LOSS train 17604206.0 valid 4036428.0
# Epoch 20:
# LOSS train 17068844.0 valid 3914066.0
# Epoch 30:
# LOSS train 16505266.0 valid 3792220.75
# Epoch 40:
# LOSS train 15979342.0 valid 3666767.5
# Epoch 50:
# LOSS train 15427230.0 valid 3547638.25
# Epoch 60:
# LOSS train 14886090.0 valid 3425793.5
# Epoch 70:
# LOSS train 14328115.0 valid 3300559.75
# Epoch 80:
# LOSS train 13754937.0 valid 3172569.5
# Epoch 90:
# LOSS train 13139170.0 valid 3034114.0
# Epoch 100:
# LOSS train 12465984.0 valid 2883598.25
# Model 29
# Epoch 10:
# LOSS train 15418510.0 valid 3546229.5
# Epoch 20:
# LOSS train 15142979.0 valid 3481478.5
# Epoch 30:
# LOSS train 14852262.0 valid 3416511.5
# Epoch 40:
# LOSS train 14573566.0 valid 3355499.5
# Epoch 50:
# LOSS train 14290699.0 valid 3291551.25
# Epoch 60:
# LOSS train 14006525.0 valid 3227835.75
# Epoch 70:
# LOSS train 13721516.0 valid 3164789.5
# Epoch 80:
# LOSS train 13426341.0 valid 3099169.0
# Epoch 90:
# LOSS train 13133760.0 valid 3033705.25
# Epoch 100:
# LOSS train 12832146.0 valid 2966088.75
# Model 30
# Epoch 10:
# LOSS train 17893880.0 valid 4105017.0
# Epoch 20:
# LOSS train 17593826.0 valid 4037438.0
# Epoch 30:
# LOSS train 17268674.0 valid 3966621.75
# Epoch 40:
# LOSS train 16930482.0 valid 3888701.0
# Epoch 50:
# LOSS train 16581496.0 valid 3809611.75
# Epoch 60:
# LOSS train 16203030.0 valid 3725786.25
# Epoch 70:
# LOSS train 15786016.0 valid 3633968.5
# Epoch 80:
# LOSS train 15352244.0 valid 3532162.0
# Epoch 90:
# LOSS train 14892821.0 valid 3431047.25
# Epoch 100:
# LOSS train 14378330.0 valid 3315222.25
# Model 31
# Epoch 10:
# LOSS train 9800931.0 valid 2294238.5
# Epoch 20:
# LOSS train 9644322.0 valid 2257200.25
# Epoch 30:
# LOSS train 9480020.0 valid 2221118.5
# Epoch 40:
# LOSS train 9301988.0 valid 2176758.0
# Epoch 50:
# LOSS train 9103498.0 valid 2134517.75
# Epoch 60:
# LOSS train 8888810.0 valid 2084955.75
# Epoch 70:
# LOSS train 8660087.0 valid 2033267.25
# Epoch 80:
# LOSS train 8414940.0 valid 1974529.25
# Epoch 90:
# LOSS train 8134163.0 valid 1905895.0
# Epoch 100:
# LOSS train 7826695.0 valid 1844073.125
# Model 32
# Epoch 10:
# LOSS train 12864641.0 valid 2978906.5
# Epoch 20:
# LOSS train 12635203.0 valid 2927497.75
# Epoch 30:
# LOSS train 12399047.0 valid 2873866.5
# Epoch 40:
# LOSS train 12146674.0 valid 2816978.5
# Epoch 50:
# LOSS train 11878706.0 valid 2756540.5
# Epoch 60:
# LOSS train 11592264.0 valid 2691290.25
# Epoch 70:
# LOSS train 11282120.0 valid 2621054.25
# Epoch 80:
# LOSS train 10942099.0 valid 2544180.5
# Epoch 90:
# LOSS train 10568719.0 valid 2457165.25
# Epoch 100:
# LOSS train 10155917.0 valid 2364607.5
# Model 33
# Epoch 10:
# LOSS train 18147760.0 valid 4156167.25
# Epoch 20:
# LOSS train 17790530.0 valid 4074614.0
# Epoch 30:
# LOSS train 17444944.0 valid 3996033.25
# Epoch 40:
# LOSS train 17073992.0 valid 3912975.75
# Epoch 50:
# LOSS train 16683984.0 valid 3826926.25
# Epoch 60:
# LOSS train 16284562.0 valid 3736313.25
# Epoch 70:
# LOSS train 15857938.0 valid 3639635.0
# Epoch 80:
# LOSS train 15384838.0 valid 3534252.0
# Epoch 90:
# LOSS train 14869800.0 valid 3418704.5
# Epoch 100:
# LOSS train 14280549.0 valid 3280749.5
# Model 34
# Epoch 10:
# LOSS train 14449160.0 valid 3332160.5
# Epoch 20:
# LOSS train 14122589.0 valid 3262086.0
# Epoch 30:
# LOSS train 13785186.0 valid 3184747.5
# Epoch 40:
# LOSS train 13457179.0 valid 3109845.0
# Epoch 50:
# LOSS train 13104110.0 valid 3030432.0
# Epoch 60:
# LOSS train 12752262.0 valid 2956024.0
# Epoch 70:
# LOSS train 12393918.0 valid 2878204.0
# Epoch 80:
# LOSS train 12053982.0 valid 2791295.25
# Epoch 90:
# LOSS train 11647924.0 valid 2700443.75
# Epoch 100:
# LOSS train 11250215.0 valid 2613358.5
# Model 35
# Epoch 10:
# LOSS train 13209548.0 valid 3051991.5
# Epoch 20:
# LOSS train 12966252.0 valid 3000805.5
# Epoch 30:
# LOSS train 12714160.0 valid 2941519.5
# Epoch 40:
# LOSS train 12443017.0 valid 2884577.25
# Epoch 50:
# LOSS train 12188956.0 valid 2821376.5
# Epoch 60:
# LOSS train 11887422.0 valid 2755251.0
# Epoch 70:
# LOSS train 11575755.0 valid 2682926.0
# Epoch 80:
# LOSS train 11228160.0 valid 2602420.5
# Epoch 90:
# LOSS train 10841471.0 valid 2509011.5
# Epoch 100:
# LOSS train 10387678.0 valid 2410277.75
# Model 36
# Epoch 10:
# LOSS train 14714808.0 valid 3395406.0
# Epoch 20:
# LOSS train 14503091.0 valid 3351637.0
# Epoch 30:
# LOSS train 14314402.0 valid 3307973.25
# Epoch 40:
# LOSS train 14107156.0 valid 3260982.5
# Epoch 50:
# LOSS train 13884863.0 valid 3211877.5
# Epoch 60:
# LOSS train 13642937.0 valid 3158710.75
# Epoch 70:
# LOSS train 13399130.0 valid 3100041.5
# Epoch 80:
# LOSS train 13138530.0 valid 3039921.5
# Epoch 90:
# LOSS train 12853760.0 valid 2976595.5
# Epoch 100:
# LOSS train 12545787.0 valid 2902320.0
# Model 37
# Epoch 10:
# LOSS train 13571214.0 valid 3138473.0
# Epoch 20:
# LOSS train 13315078.0 valid 3079967.0
# Epoch 30:
# LOSS train 13044612.0 valid 3019125.25
# Epoch 40:
# LOSS train 12753943.0 valid 2954189.5
# Epoch 50:
# LOSS train 12451292.0 valid 2884583.25
# Epoch 60:
# LOSS train 12126490.0 valid 2809296.0
# Epoch 70:
# LOSS train 11771674.0 valid 2731244.5
# Epoch 80:
# LOSS train 11390413.0 valid 2643317.5
# Epoch 90:
# LOSS train 10986983.0 valid 2550517.0
# Epoch 100:
# LOSS train 10536058.0 valid 2446598.5
# Model 38
# Epoch 10:
# LOSS train 18998860.0 valid 4353801.0
# Epoch 20:
# LOSS train 18693728.0 valid 4280632.5
# Epoch 30:
# LOSS train 18339292.0 valid 4206888.5
# Epoch 40:
# LOSS train 17987416.0 valid 4129476.75
# Epoch 50:
# LOSS train 17589964.0 valid 4041031.0
# Epoch 60:
# LOSS train 17174486.0 valid 3945267.5
# Epoch 70:
# LOSS train 16707140.0 valid 3836886.75
# Epoch 80:
# LOSS train 16192754.0 valid 3725684.25
# Epoch 90:
# LOSS train 15652085.0 valid 3596413.75
# Epoch 100:
# LOSS train 14971440.0 valid 3453685.25
# Model 39
# Epoch 10:
# LOSS train 15541634.0 valid 3573666.0
# Epoch 20:
# LOSS train 15306680.0 valid 3521460.0
# Epoch 30:
# LOSS train 15075783.0 valid 3469372.0
# Epoch 40:
# LOSS train 14840267.0 valid 3416043.5
# Epoch 50:
# LOSS train 14599564.0 valid 3363024.25
# Epoch 60:
# LOSS train 14351837.0 valid 3307186.5
# Epoch 70:
# LOSS train 14104867.0 valid 3250536.0
# Epoch 80:
# LOSS train 13843727.0 valid 3191293.25
# Epoch 90:
# LOSS train 13564213.0 valid 3130880.5
# Epoch 100:
# LOSS train 13285882.0 valid 3063692.25

# %%
trainreport_name = './drive/MyDrive/CHB_trainreport.csv'

# %%
model.to_csv(trainreport_name)

# %% [markdown]
# ### Evaluate model

# %%
score=Z_score(np.sum(np.median(t_err, axis=0), axis=-1))

# %%
evaluate(trainlabel, score)
